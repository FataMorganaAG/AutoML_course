# %% [markdown]
# # Загрузка библиотек

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.5.0-py3-none-any.whl (413 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.4/413.4 kB 8.9 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 16.0 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.23)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.0 alembic-1.13.1 colorlog-6.8.0 optuna-3.5.0

# %% [markdown]
# # Импорты

# %%
import pandas as pd
import numpy as np
import torch

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import log_loss

import optuna
from functools import partial
from collections import OrderedDict
import scipy

import warnings
warnings.filterwarnings("ignore")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Загрузка даанных

# %%
train = pd.read_csv('/content/drive/MyDrive/automl/train_p.csv')
test = pd.read_csv('/content/drive/MyDrive/automl/test_p.csv')

# %%
train.head(3)
# Out:
#    Unnamed: 0  discourse_id      essay_id  \
# 0        4546  61ba01f9c332  51634BBDF223
# 1       21829  ea75b33c79ed  65991D1DA389
# 2       16662  18a514017021  20D0120E0F48
#
#                                       discourse_text discourse_type  \
# 0  kn the planet but he also comes up with idea o...          Claim
# 1  When your phone is turned on someone can call ...       Evidence
# 2  or else there will be people saying that the c...       Evidence
#
#   discourse_effectiveness  discourse_effectiveness_map
# 0                Adequate                            1
# 1                Adequate                            1
# 2                Adequate                            1

# %%
test.head(3)
# Out:
#    Unnamed: 0  discourse_id      essay_id  \
# 0       36023  9b1e3093f8c0  D282E21C2DB1
# 1       34198  714ae42d8d54  4C6B05BD5A81
# 2       15341  b35015e761cd  0CFDDC1CF75A
#
#                                       discourse_text discourse_type  \
# 0                                        avoid bias           Claim
# 1  Some students have a slower learning abilities...       Evidence
# 2  I think they should not let them to bring cell...       Position
#
#   discourse_effectiveness  discourse_effectiveness_map
# 0               Effective                            2
# 1                Adequate                            1
# 2                Adequate                            1

# %%
del train['Unnamed: 0']

# %%
del test['Unnamed: 0']

# %%
train.head(3)
# Out:
#    discourse_id      essay_id  \
# 0  61ba01f9c332  51634BBDF223
# 1  ea75b33c79ed  65991D1DA389
# 2  18a514017021  20D0120E0F48
#
#                                       discourse_text discourse_type  \
# 0  kn the planet but he also comes up with idea o...          Claim
# 1  When your phone is turned on someone can call ...       Evidence
# 2  or else there will be people saying that the c...       Evidence
#
#   discourse_effectiveness  discourse_effectiveness_map
# 0                Adequate                            1
# 1                Adequate                            1
# 2                Adequate                            1

# %%
test.head(3)
# Out:
#    discourse_id      essay_id  \
# 0  9b1e3093f8c0  D282E21C2DB1
# 1  714ae42d8d54  4C6B05BD5A81
# 2  b35015e761cd  0CFDDC1CF75A
#
#                                       discourse_text discourse_type  \
# 0                                        avoid bias           Claim
# 1  Some students have a slower learning abilities...       Evidence
# 2  I think they should not let them to bring cell...       Position
#
#   discourse_effectiveness  discourse_effectiveness_map
# 0               Effective                            2
# 1                Adequate                            1
# 2                Adequate                            1

# %% [markdown]
# # Модель и оптимизация

# %% [markdown]
# * TFIdf Vect
# * LogReg Model
# * Model Optimization with Optuna

# %%
text_col = "discourse_text"
target_col = "discourse_effectiveness"
target_enc = LabelEncoder()
target_enc.fit(train[target_col])
# Out:
# LabelEncoder()

# %%
train[target_col] = target_enc.transform(train[target_col])

# %%
lenc = LabelEncoder()
lenc.fit(train.discourse_type)

train.discourse_type = lenc.transform(train.discourse_type)
test.discourse_type = lenc.transform(test.discourse_type)

# %%
len(train.discourse_id.unique()) == train.shape[0]
# Out:
# True

# %%
def objective(trial, dset: pd.DataFrame, text_col: str = "discourse_text", target_col: str = "discourse_effectiveness", alpha: float = 0.1):

    ngram = trial.suggest_categorical("preprocess_vect_ngram_range", [(1, 2), (1, 3), (2, 4), (2, 3), (1, 1)])
    max_feats = trial.suggest_int("preprocess_vect_max_features", 1e4, 1e6)
    lowercase = trial.suggest_categorical("preprocess_vect_lowercase", [True, False])
    stopwords = trial.suggest_categorical("preprocess_vect_stop_words", [None, "english"])

    C = trial.suggest_loguniform("model_lr_C", 0.1234, 1)
    class_weight = trial.suggest_categorical("model_lr_class_weight", ["balanced", None])

    scores = []
    skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42).split(dset[target_col], dset[target_col])
    for tr_ix, vl_ix in skf:
        train, vl_df = dset.iloc[tr_ix], dset.iloc[vl_ix]

        vect = TfidfVectorizer(ngram_range=ngram, max_features=max_feats, lowercase=lowercase)
        vect.fit(train[text_col])

        train_vecs = vect.transform(train[text_col])
        valid_vecs = vect.transform(vl_df[text_col])

        train_vecs = scipy.sparse.hstack([train_vecs, scipy.sparse.csr_matrix(train.discourse_type.values).T])
        valid_vecs = scipy.sparse.hstack([valid_vecs, scipy.sparse.csr_matrix(vl_df.discourse_type.values).T])

        train_y, valid_y = train[target_col], vl_df[target_col]

        model = LogisticRegression(C=C,
                                   class_weight=class_weight,
                                   n_jobs=-1,
                                   max_iter=5000)
        model.fit(train_vecs, train_y)
        probas = model.predict_proba(valid_vecs)
        score = log_loss(valid_y, probas)

        scores.append(score)

    mean = np.mean(scores)
    std = np.std(score)

    return mean + alpha * std

def parse_logs(params: dict):
    p = dict.fromkeys(["model", "preprocessing"])
    p["model"] = dict()
    p["preprocess"] = dict()
    for key, value in params.items():
        identifiers = key.split("_", 2)
        hyperparam = identifiers[-1]
        p[identifiers[0]][hyperparam] = value
    return p

# %%
study = optuna.create_study(direction="minimize")
objective = partial(objective, dset=train)
study.optimize(objective, n_trials=30)
# Out:
# [I 2023-12-28 08:36:17,839] A new study created in memory with name: no-name-14aecf24-a573-4968-a29f-dfdb092cea88
# [I 2023-12-28 08:37:21,946] Trial 0 finished with value: 0.8466979394405981 and parameters: {'preprocess_vect_ngram_range': (1, 2), 'preprocess_vect_max_features': 991935, 'preprocess_vect_lowercase': False, 'preprocess_vect_stop_words': None, 'model_lr_C': 0.13232973324173522, 'model_lr_class_weight': None}. Best is trial 0 with value: 0.8466979394405981.
# [I 2023-12-28 08:38:23,679] Trial 1 finished with value: 0.7966563506059474 and parameters: {'preprocess_vect_ngram_range': (1, 2), 'preprocess_vect_max_features': 134092, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.5929386451329182, 'model_lr_class_weight': None}. Best is trial 1 with value: 0.7966563506059474.
# [I 2023-12-28 08:39:16,829] Trial 2 finished with value: 0.836791498845694 and parameters: {'preprocess_vect_ngram_range': (1, 2), 'preprocess_vect_max_features': 389823, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': None, 'model_lr_C': 0.16317171336677733, 'model_lr_class_weight': None}. Best is trial 1 with value: 0.7966563506059474.
# [I 2023-12-28 08:41:05,593] Trial 3 finished with value: 0.8684901296674324 and parameters: {'preprocess_vect_ngram_range': (1, 2), 'preprocess_vect_max_features': 946940, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': None, 'model_lr_C': 0.9206664406950288, 'model_lr_class_weight': 'balanced'}. Best is trial 1 with value: 0.7966563506059474.
# [I 2023-12-28 08:41:43,157] Trial 4 finished with value: 0.9045877320999113 and parameters: {'preprocess_vect_ngram_range': (1, 3), 'preprocess_vect_max_features': 19658, 'preprocess_vect_lowercase': False, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.24860443771450744, 'model_lr_class_weight': 'balanced'}. Best is trial 1 with value: 0.7966563506059474.
# [I 2023-12-28 08:44:22,234] Trial 5 finished with value: 0.8303548584285539 and parameters: {'preprocess_vect_ngram_range': (2, 3), 'preprocess_vect_max_features': 386517, 'preprocess_vect_lowercase': False, 'preprocess_vect_stop_words': None, 'model_lr_C': 0.9908768337074174, 'model_lr_class_weight': None}. Best is trial 1 with value: 0.7966563506059474.
# [I 2023-12-28 08:44:44,098] Trial 6 finished with value: 0.7986555802603457 and parameters: {'preprocess_vect_ngram_range': (1, 1), 'preprocess_vect_max_features': 352372, 'preprocess_vect_lowercase': False, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.6432311099161385, 'model_lr_class_weight': None}. Best is trial 1 with value: 0.7966563506059474.
# [I 2023-12-28 08:45:04,344] Trial 7 finished with value: 0.8998605426461114 and parameters: {'preprocess_vect_ngram_range': (1, 1), 'preprocess_vect_max_features': 672823, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.4994431715977002, 'model_lr_class_weight': 'balanced'}. Best is trial 1 with value: 0.7966563506059474.
# [I 2023-12-28 08:46:10,407] Trial 8 finished with value: 0.7981128355348682 and parameters: {'preprocess_vect_ngram_range': (1, 3), 'preprocess_vect_max_features': 89208, 'preprocess_vect_lowercase': False, 'preprocess_vect_stop_words': None, 'model_lr_C': 0.5389044689913732, 'model_lr_class_weight': None}. Best is trial 1 with value: 0.7966563506059474.
# [I 2023-12-28 08:46:27,085] Trial 9 finished with value: 0.8089508174502867 and parameters: {'preprocess_vect_ngram_range': (1, 1), 'preprocess_vect_max_features': 126832, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.31533664428519936, 'model_lr_class_weight': None}. Best is trial 1 with value: 0.7966563506059474.
# [I 2023-12-28 08:49:41,693] Trial 10 finished with value: 0.9537517595158734 and parameters: {'preprocess_vect_ngram_range': (2, 4), 'preprocess_vect_max_features': 598389, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.3875338117791773, 'model_lr_class_weight': 'balanced'}. Best is trial 1 with value: 0.7966563506059474.
# [I 2023-12-28 08:51:08,905] Trial 11 finished with value: 0.7992338821554389 and parameters: {'preprocess_vect_ngram_range': (1, 3), 'preprocess_vect_max_features': 191081, 'preprocess_vect_lowercase': False, 'preprocess_vect_stop_words': None, 'model_lr_C': 0.5726092648280288, 'model_lr_class_weight': None}. Best is trial 1 with value: 0.7966563506059474.
# [I 2023-12-28 08:52:41,647] Trial 12 finished with value: 0.796440856722949 and parameters: {'preprocess_vect_ngram_range': (1, 3), 'preprocess_vect_max_features': 176720, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.6574531137794092, 'model_lr_class_weight': None}. Best is trial 12 with value: 0.796440856722949.
# [I 2023-12-28 08:54:21,460] Trial 13 finished with value: 0.833728100696011 and parameters: {'preprocess_vect_ngram_range': (2, 3), 'preprocess_vect_max_features': 253202, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.7498465268134787, 'model_lr_class_weight': None}. Best is trial 12 with value: 0.796440856722949.
# [I 2023-12-28 08:56:01,639] Trial 14 finished with value: 0.8578068866527403 and parameters: {'preprocess_vect_ngram_range': (2, 4), 'preprocess_vect_max_features': 247844, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.3773989804826519, 'model_lr_class_weight': None}. Best is trial 12 with value: 0.796440856722949.
# [I 2023-12-28 09:01:18,373] Trial 15 finished with value: 0.8023416796145804 and parameters: {'preprocess_vect_ngram_range': (1, 3), 'preprocess_vect_max_features': 734469, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.7479068541184991, 'model_lr_class_weight': None}. Best is trial 12 with value: 0.796440856722949.
# [I 2023-12-28 09:01:46,206] Trial 16 finished with value: 0.7963445430304401 and parameters: {'preprocess_vect_ngram_range': (1, 2), 'preprocess_vect_max_features': 16180, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.4561676670385534, 'model_lr_class_weight': None}. Best is trial 16 with value: 0.7963445430304401.
# [I 2023-12-28 09:02:30,459] Trial 17 finished with value: 0.8107477684180471 and parameters: {'preprocess_vect_ngram_range': (1, 3), 'preprocess_vect_max_features': 29232, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.25606519668713174, 'model_lr_class_weight': None}. Best is trial 16 with value: 0.7963445430304401.
# [I 2023-12-28 09:03:54,533] Trial 18 finished with value: 0.8980218259452143 and parameters: {'preprocess_vect_ngram_range': (1, 2), 'preprocess_vect_max_features': 485236, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.4255010150955455, 'model_lr_class_weight': 'balanced'}. Best is trial 16 with value: 0.7963445430304401.
# [I 2023-12-28 09:05:30,302] Trial 19 finished with value: 0.8703883436316097 and parameters: {'preprocess_vect_ngram_range': (2, 4), 'preprocess_vect_max_features': 283224, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.2812390923919126, 'model_lr_class_weight': None}. Best is trial 16 with value: 0.7963445430304401.
# [I 2023-12-28 09:07:29,282] Trial 20 finished with value: 0.894585058543846 and parameters: {'preprocess_vect_ngram_range': (2, 3), 'preprocess_vect_max_features': 843040, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.1965689748277928, 'model_lr_class_weight': None}. Best is trial 16 with value: 0.7963445430304401.
# [I 2023-12-28 09:08:27,111] Trial 21 finished with value: 0.8016536744947774 and parameters: {'preprocess_vect_ngram_range': (1, 2), 'preprocess_vect_max_features': 122547, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.4562334089304632, 'model_lr_class_weight': None}. Best is trial 16 with value: 0.7963445430304401.
# [I 2023-12-28 09:09:45,196] Trial 22 finished with value: 0.7960462035032715 and parameters: {'preprocess_vect_ngram_range': (1, 2), 'preprocess_vect_max_features': 169757, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.6392097609506208, 'model_lr_class_weight': None}. Best is trial 22 with value: 0.7960462035032715.
# [I 2023-12-28 09:11:38,532] Trial 23 finished with value: 0.7951354846879545 and parameters: {'preprocess_vect_ngram_range': (1, 2), 'preprocess_vect_max_features': 500527, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.7186636918429296, 'model_lr_class_weight': None}. Best is trial 23 with value: 0.7951354846879545.
# [I 2023-12-28 09:13:25,517] Trial 24 finished with value: 0.7929434980083846 and parameters: {'preprocess_vect_ngram_range': (1, 2), 'preprocess_vect_max_features': 475485, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.8507706156998376, 'model_lr_class_weight': None}. Best is trial 24 with value: 0.7929434980083846.
# [I 2023-12-28 09:15:02,317] Trial 25 finished with value: 0.7937296653189514 and parameters: {'preprocess_vect_ngram_range': (1, 2), 'preprocess_vect_max_features': 491683, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.7961049223306641, 'model_lr_class_weight': None}. Best is trial 24 with value: 0.7929434980083846.
# [I 2023-12-28 09:16:54,518] Trial 26 finished with value: 0.8725434317586922 and parameters: {'preprocess_vect_ngram_range': (1, 2), 'preprocess_vect_max_features': 511299, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.8172935695232706, 'model_lr_class_weight': 'balanced'}. Best is trial 24 with value: 0.7929434980083846.
# [I 2023-12-28 09:18:49,616] Trial 27 finished with value: 0.7928633498367872 and parameters: {'preprocess_vect_ngram_range': (1, 2), 'preprocess_vect_max_features': 500609, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.8563265999714489, 'model_lr_class_weight': None}. Best is trial 27 with value: 0.7928633498367872.
# [I 2023-12-28 09:20:41,775] Trial 28 finished with value: 0.7930852902955815 and parameters: {'preprocess_vect_ngram_range': (1, 2), 'preprocess_vect_max_features': 608846, 'preprocess_vect_lowercase': True, 'preprocess_vect_stop_words': 'english', 'model_lr_C': 0.8397718918325737, 'model_lr_class_weight': None}. Best is trial 27 with value: 0.7928633498367872.
# [I 2023-12-28 09:22:44,429] Trial 29 finished with value: 0.7916165248322292 and parameters: {'preprocess_vect_ngram_range': (1, 2), 'preprocess_vect_max_features': 652300, 'preprocess_vect_lowercase': False, 'preprocess_vect_stop_words': None, 'model_lr_C': 0.9029771623520488, 'model_lr_class_weight': None}. Best is trial 29 with value: 0.7916165248322292.

# %%
opt_params = parse_logs(study.best_params)
model_params = opt_params["model"]
preprocess_params = opt_params["preprocess"]

# %%
test_preds = []
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42).split(train[target_col], train[target_col])
for tr_ix, vl_ix in skf:
    train_df, _ = train.iloc[tr_ix], train.iloc[vl_ix]

    vect = TfidfVectorizer(**preprocess_params)
    vect.fit(train_df[text_col])

    train_vecs = vect.transform(train_df[text_col])
    test_vecs = vect.transform(test[text_col])

    train_vecs = scipy.sparse.hstack([train_vecs, scipy.sparse.csr_matrix(train_df.discourse_type.values).T])
    test_vecs = scipy.sparse.hstack([test_vecs, scipy.sparse.csr_matrix(test.discourse_type.values).T])

    train_y = train_df[target_col]

    model = LogisticRegression(**model_params, max_iter=5000)
    model.fit(train_vecs, train_y)
    probas = model.predict_proba(test_vecs)

    test_preds.append(probas)

# %%
prob_preds = np.mean(np.array(test_preds), axis=0)

# %%
prob_preds
# Out:
# array([[0.53206178, 0.29974147, 0.16819675],
#        [0.41286943, 0.47995766, 0.10717291],
#        [0.8829141 , 0.01571764, 0.10136826],
#        ...,
#        [0.40040439, 0.29407352, 0.30552209],
#        [0.53159752, 0.07298454, 0.39541793],
#        [0.57353934, 0.22936366, 0.19709701]])

# %%
sub = pd.DataFrame(prob_preds, columns=target_enc.classes_)
sub["discourse_id"] = test["discourse_id"]

# %%
sub
# Out:
#       Adequate  Effective  Ineffective  discourse_id
# 0     0.532062   0.299741     0.168197  9b1e3093f8c0
# 1     0.412869   0.479958     0.107173  714ae42d8d54
# 2     0.882914   0.015718     0.101368  b35015e761cd
# 3     0.489417   0.224186     0.286398  32245eafbe92
# 4     0.242814   0.722376     0.034810  7e946ef44860
# ...        ...        ...          ...           ...
# 7334  0.134792   0.058736     0.806471  d863083c5f22
# 7335  0.567083   0.172085     0.260832  57d92e1dddb3
# 7336  0.400404   0.294074     0.305522  02aca137ea9e
# 7337  0.531598   0.072985     0.395418  325a46d9f889
# 7338  0.573539   0.229364     0.197097  916f3396980a
#
# [7339 rows x 4 columns]

# %%
logloss = log_loss(test[target_col], prob_preds)
logloss
# Out:
# 0.7832725916621214
